# %% [markdown]
# # Traffic for Louisville

# %%
import pandas as pd
import csv
import zipfile as z
import sqlite3
import matplotlib.pyplot as plt
import os

os.getcwd()
# Out:
# 'C:\\Users\\reeva\\Documents\\code\\github\\traffic_project'

# %% [markdown]
# ### Load the csv

# %%
# unzipping csv

#zf = z.ZipFile("Data/JEFFERSON COUNTY_CRASH DATA_2010-2017.zip","r")
#zf.extractall("Data")
#zf.close()

# %%
# sqlite DB

db = sqlite3.connect("Data/traffic_project.db")
#df1 = pd.read_csv("Data/JEFFERSON COUNTY_CRASH DATA_2010-2017.csv", header=0)
df1 = pd.read_csv("Data/traffic_quarterly.csv", header=0)
df1.to_sql("traffic", db, if_exists="replace")

def run_query(query):
    return pd.read_sql_query(query,db)
# Out:
# C:\Users\reeva\Anaconda3\lib\site-packages\pandas\core\generic.py:2712: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
# delete csv file

#target_file = "Data/JEFFERSON COUNTY_CRASH DATA_2010-2017.csv"
  
#if os.path.isfile(target_file): 
#    os.remove(target_file) 
#    print("File deleted") 
#else: 
#    print(f'"{target_file}" not found')

# %% [markdown]
# ### Table information via SQL

# %%
# table information

query = """SELECT * FROM sqlite_master ORDER BY name;"""
run_query(query)
# Out:
#     type              name tbl_name  rootpage  \
# 0  index  ix_traffic_index  traffic       133
# 1  table           traffic  traffic         2
#
#                                                  sql
# 0  CREATE INDEX "ix_traffic_index"ON "traffic" ("...
# 1  CREATE TABLE "traffic" (\n"index" INTEGER,\n  ...

# %%
# View whole table

query = """SELECT * FROM traffic;"""
run_query(query)
# Out:
#     index  Year   "First Quarter"   "Second Quarter"   "Third Quarter"  \
# 0       0  2007              9354              10611             11056
# 1       1  2008              8459               9435              9947
# 2       2  2009              7552               8975              9104
# 3       3  2010              6755               8522              9226
# 4       4  2011              6726               8227              8984
# 5       5  2012              7521               8612              9171
# 6       6  2013              7166               8207              9024
# 7       7  2014              6856               8179              8799
# 8       8  2015              7370               8823              9805
# 9       9  2016              8154               9563             10078
# 10     10  2017              8301               9460             10081
# 11     11  2018              8189               9290              9856
# 12     12  2019              7830               9150              9750
#
#     "Fourth Quarter"  "Total"   "First Nine Months"
# 0              10238    41259                 31021
# 1               9582    37423                 27841
# 2               8252    33883                 25631
# 3               8496    32999                 24503
# 4               8542    32479                 23937
# 5               8478    33782                 25304
# 6               8496    32893                 24397
# 7               8910    32744                 23834
# 8               9486    35484                 25998
# 9              10011    37806                 27795
# 10              9631    37473                 27842
# 11              9225    36560                 27335
# 12                                            26730

# %%
# Limiting selection to the data for the graph

# For some reason I can't read the other columns

query = """
SELECT 
Year, "First Quarter", "Second Quarter"
FROM traffic;
"""
run_query(query)
# Out:
#     Year "First Quarter" "Second Quarter"
# 0   2007   First Quarter   Second Quarter
# 1   2008   First Quarter   Second Quarter
# 2   2009   First Quarter   Second Quarter
# 3   2010   First Quarter   Second Quarter
# 4   2011   First Quarter   Second Quarter
# 5   2012   First Quarter   Second Quarter
# 6   2013   First Quarter   Second Quarter
# 7   2014   First Quarter   Second Quarter
# 8   2015   First Quarter   Second Quarter
# 9   2016   First Quarter   Second Quarter
# 10  2017   First Quarter   Second Quarter
# 11  2018   First Quarter   Second Quarter
# 12  2019   First Quarter   Second Quarter

# %% [markdown]
# ### Early graph information

# %%
#input_file = 'iris.csv'
plt.figure(figsize=(7.5, 4.25))
plt.style.use('classic')

traffic_incidents = [][]

for quarter in range()

#with open(input_file, 'r') as iris_data:
#    irises = list(csv.reader(iris_data))
    
#virginica_petal_length = []

num_bins = 5

for petal in range(0, len(irises)-1):
    if irises[petal][4] == 'Iris-virginica':
        virginica_petal_length.append(float(irises[petal][2]))
        
plt.hist(virginica_petal_length, num_bins, facecolor='red', alpha=0.75)

plt.title('Iris-virginica Petal length', fontsize=12)
plt.xlabel('Petal length (cm)', fontsize=10)
plt.ylabel('Probability', fontsize=10)

plt.show()
