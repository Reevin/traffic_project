# %% [markdown]
# # Traffic for Louisville

# %%
import pandas as pd
import zipfile as z
import sqlite3
import os

os.getcwd()
# Out:
# 'C:\\Users\\reeva\\Documents\\code\\github\\traffic_project'

# %%
# unzipping csv

zf = z.ZipFile("Data/JEFFERSON COUNTY_CRASH DATA_2010-2017.zip","r")
zf.extractall("Data")
zf.close()

# %%
# sqlite DB

db = sqlite3.connect("Data/traffic_project.db")
df1 = pd.read_csv("Data/JEFFERSON COUNTY_CRASH DATA_2010-2017.csv", header=0)
df1.to_sql("traffic", db, if_exists="replace")

def run_query(query):
    return pd.read_sql_query(query,db)
# Out:
# C:\Users\reeva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,14,28,30,37,39,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\reeva\Anaconda3\lib\site-packages\pandas\core\generic.py:2712: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
# delete csv file

target_file = "Data/JEFFERSON COUNTY_CRASH DATA_2010-2017.csv"
  
if os.path.isfile(target_file): 
    os.remove(target_file) 
    print("File deleted") 
else: 
    print(f'"{target_file}" not found')
# Out:
# File deleted

# %%
# table information

query = """SELECT * FROM sqlite_master ORDER BY name;"""
run_query(query)
# Out:
#     type              name tbl_name  rootpage  \
# 0  index  ix_traffic_index  traffic     20293
# 1  table           traffic  traffic         2
#
#                                                  sql
# 0  CREATE INDEX "ix_traffic_index"ON "traffic" ("...
# 1  CREATE TABLE "traffic" (\n"index" INTEGER,\n  ...

# %%
query = """SELECT * FROM traffic;"""
run_query(query)
# Out:
#          index  MASTER FILE NUMBER          INVESTIGATING AGENCY  LOCAL CODE  \
# 0            0              336868  LOUISVILLE METRO POLICE DEPT  8010009447
# 1            1              336869  LOUISVILLE METRO POLICE DEPT  8010009784
# 2            2              336871  LOUISVILLE METRO POLICE DEPT  8010013765
# 3            3              336872  LOUISVILLE METRO POLICE DEPT        None
# 4            4              337553  LOUISVILLE METRO POLICE DEPT  8010007753
# ...        ...                 ...                           ...         ...
# 255536  255536            72135357  LOUISVILLE METRO POLICE DEPT  8018000117
# 255537  255537            72135358  LOUISVILLE METRO POLICE DEPT  8018000124
# 255538  255538            72135359  LOUISVILLE METRO POLICE DEPT  8018000133
# 255539  255539            72135360  LOUISVILLE METRO POLICE DEPT  8018000140
# 255540  255540            72136934     SHIVELY POLICE DEPARTMENT  04-18-0000
#
#        COLLISION STATUS CODE  COUNTY NAME ROADWAY NUMBER BLOCK/HOUSE #  \
# 0                         AC           56       I 0065            None
# 1                         AC           56           None          None
# 2                         AC           56           None          None
# 3                         AC           56           None          None
# 4                         AC           56           None          None
# ...                      ...          ...            ...           ...
# 255536                    AC           56       KY1020
# 255537                    AC           56
# 255538                    AC           56       I 0065
# 255539                    AC           56       KY1747
# 255540                    AC           56       US0031W          3900B
#
#        ROADWAY NAME ROADWAY SUFFIX  ...  \
# 0               I65           None  ...
# 1         JEFFERSON          ST     ...
# 2             ADAMS          ST     ...
# 3              MAIN          ST     ...
# 4             DIXIE          HWY    ...
# ...             ...            ...  ...
# 255536          3RD          ST     ...
# 255537        FLOYD          ST     ...
# 255538         None                 ...
# 255539  HURSTBOURNE          PKWY   ...
# 255540        DIXIE          HWY    ...
#
#                                      DIRECTIONAL ANALYSIS  \
# 0          REAR END IN TRAFFIC LANES BOTH VEHICLES MOVING
# 1              ANGLE COLLISION - ONE VEHICLE TURNING LEFT
# 2       1 VEHICLE PARKED POSITION (NOT PARKING LOT/DRI...
# 3                                        VEHICLE BACKING
# 4                                SIDESWIPE-SAME DIRECTION
# ...                                                   ...
# 255536                           SIDESWIPE-SAME DIRECTION
# 255537     ANGLE COLLISION - BOTH VEHICLES GOING STRAIGHT
# 255538                                 REAR END - ON RAMP
# 255539                           SIDESWIPE-SAME DIRECTION
# 255540               OTHER ROADWAY OR MID-BLOCK COLLISION
#
#         MANNER OF COLLISION CODE       MANNER OF COLLISION  \
# 0                            5.0                  REAR END
# 1                            1.0                     ANGLE
# 2                            5.0                  REAR END
# 3                            2.0                   BACKING
# 4                            8.0  SIDESWIPE-SAME DIRECTION
# ...                          ...                       ...
# 255536                        08  SIDESWIPE-SAME DIRECTION
# 255537                        01                     ANGLE
# 255538                        05                  REAR END
# 255539                        08  SIDESWIPE-SAME DIRECTION
# 255540                        04        OPPOSING LEFT TURN
#
#         ROADWAY CHARACTER CODE ROADWAY CHARACTER LIGHT CONDITION CODE  \
# 0                          6.0  STRAIGHT & LEVEL                  2.0
# 1                          6.0  STRAIGHT & LEVEL                  2.0
# 2                          6.0  STRAIGHT & LEVEL                  2.0
# 3                          6.0  STRAIGHT & LEVEL                  2.0
# 4                          6.0  STRAIGHT & LEVEL                  2.0
# ...                        ...               ...                  ...
# 255536                      06  STRAIGHT & LEVEL                   05
# 255537                      06  STRAIGHT & LEVEL                   02
# 255538                      03     CURVE & LEVEL                   02
# 255539                      06  STRAIGHT & LEVEL                   02
# 255540                      04  STRAIGHT & GRADE                   06
#
#              LIGHT CONDITION RAMP FROM ROADWAY ID RAMP TO ROADWAY ID  \
# 0                   DAYLIGHT                 None               None
# 1                   DAYLIGHT                 None               None
# 2                   DAYLIGHT                 None               None
# 3                   DAYLIGHT                 None               None
# 4                   DAYLIGHT                 None               None
# ...                      ...                  ...                ...
# 255536   DARK-HWY LIGHTED/ON                 None               None
# 255537              DAYLIGHT                 None               None
# 255538              DAYLIGHT               I 0065             I 0065
# 255539              DAYLIGHT                 None               None
# 255540  DARK-HWY NOT LIGHTED                 None               None
#
#        SECONDARY COLLISION INDICATOR
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# ...                              ...
# 255536                             N
# 255537                             N
# 255538                             N
# 255539                             N
# 255540                             N
#
# [255541 rows x 47 columns]
